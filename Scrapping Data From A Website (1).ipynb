# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"US/Eastern\"")

# %%
hex_project_id = _hex_json.loads("\"2a283e91-bbec-4998-b252-c51e9e4e2078\"")

# %%
hex_project_name = _hex_json.loads("\"Scrapping Data From A Website\"")

# %%
hex_status = _hex_json.loads("\"\"")

# %%
hex_categories = _hex_json.loads("[]")

# %%
hex_color_palette = _hex_json.loads("[\"#4C78A8\",\"#F58518\",\"#E45756\",\"#72B7B2\",\"#54A24B\",\"#EECA3B\",\"#B279A2\",\"#FF9DA6\",\"#9D755D\",\"#BAB0AC\"]")

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://webpages.charlotte.edu/mscipion/"

r= requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text, "lxml")

# %%
table = soup.find("table", class_="table table-sm table-hover screenertable")
print(table)     #uncomment to see full outp
# Out:
# None

# %%
if "soup" not in locals() or soup is None:
    print("Soup object is not defined or is None.")
else:
    # Find the table within the soup
    table = soup.find("table")
    if table is not None:
        headers = table.find_all("th")
        print(headers)
    else:
        print("No table found in the soup object.")
# Out:
# [<th>Student</th>, <th>Favourite Computer Language</th>, <th>Years of Experience</th>]

# %%
titles = []

for i in headers:
    title = i.text
    titles.append(title)
    
print(titles)
# Out:
# ['Student', 'Favourite Computer Language', 'Years of Experience']

# %%
df= pd.DataFrame(columns=titles)
print(df)
# Out:
# Empty DataFrame
# Columns: [Student, Favourite Computer Language, Years of Experience]
# Index: []

# %%
rows = table.find_all("tr")
print(rows)           #uncomment to see full output
# Out:
# [<tr>
# <th>Student</th>
# <th>Favourite Computer Language</th>
# <th>Years of Experience</th>
# </tr>, <tr>
# <td>Fred</td>
# <td>Kotlin</td>
# <td>4</td>
# </tr>, <tr>
# <td>Paula</td>
# <td>Python</td>
# <td>2</td>
# </tr>, <tr>
# <td>Ernst</td>
# <td>Java</td>
# <td>7</td>
# </tr>, <tr>
# <td>Isabel</td>
# <td>C++</td>
# <td>3</td>
# </tr>, <tr>
# <td>Tony</td>
# <td>Pearl</td>
# <td>7</td>
# </tr>, <tr>
# <td>Maria</td>
# <td>Cobol</td>
# <td>15</td>
# </tr>]

# %%
for i in rows[1:]:
    print(i)
# Out:
# <tr>
# <td>Fred</td>
# <td>Kotlin</td>
# <td>4</td>
# </tr>
# <tr>
# <td>Paula</td>
# <td>Python</td>
# <td>2</td>
# </tr>
# <tr>
# <td>Ernst</td>
# <td>Java</td>
# <td>7</td>
# </tr>
# <tr>
# <td>Isabel</td>
# <td>C++</td>
# <td>3</td>
# </tr>
# <tr>
# <td>Tony</td>
# <td>Pearl</td>
# <td>7</td>
# </tr>
# <tr>
# <td>Maria</td>
# <td>Cobol</td>
# <td>15</td>
# </tr>

# %%
for i in rows[1:]:
    data = table.find_all("td")
    print(data)
# Out:
# [<td>Fred</td>, <td>Kotlin</td>, <td>4</td>, <td>Paula</td>, <td>Python</td>, <td>2</td>, <td>Ernst</td>, <td>Java</td>, <td>7</td>, <td>Isabel</td>, <td>C++</td>, <td>3</td>, <td>Tony</td>, <td>Pearl</td>, <td>7</td>, <td>Maria</td>, <td>Cobol</td>, <td>15</td>]
# [<td>Fred</td>, <td>Kotlin</td>, <td>4</td>, <td>Paula</td>, <td>Python</td>, <td>2</td>, <td>Ernst</td>, <td>Java</td>, <td>7</td>, <td>Isabel</td>, <td>C++</td>, <td>3</td>, <td>Tony</td>, <td>Pearl</td>, <td>7</td>, <td>Maria</td>, <td>Cobol</td>, <td>15</td>]
# [<td>Fred</td>, <td>Kotlin</td>, <td>4</td>, <td>Paula</td>, <td>Python</td>, <td>2</td>, <td>Ernst</td>, <td>Java</td>, <td>7</td>, <td>Isabel</td>, <td>C++</td>, <td>3</td>, <td>Tony</td>, <td>Pearl</td>, <td>7</td>, <td>Maria</td>, <td>Cobol</td>, <td>15</td>]
# ...

# %%
for i in rows[1:]:
    data = i.find_all("td")
    row = [tr.text.strip() for tr in data]
    df.loc[len(df)] = row

df.head(6)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Student</th>
#       <th>Favourite Computer Language</th>
#       <th>Years of Experience</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Fred</td>
#       <td>Kotlin</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Paula</td>
#       <td>Python</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ernst</td>
#       <td>Java</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Isabel</td>
#       <td>C++</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Tony</td>
# ...
